# %% [markdown]
# # **Netflix Dataset Overview**

# %% [markdown]
# ### **Project Objective**

# %% [markdown]
# **The objective of this project is to perform exploratory data analysis (EDA) on Netflix Movies and TV Shows data to identify content distribution patterns, genre trends, country-wise contributions, rating distributions, and growth of Netflix content over time.**

# %% [markdown]
# #### **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### **Load Dataset**

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\netflix_titles.csv.zip")

# %% [markdown]
# #### **First 5 Rows of Dataset**

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #### **Dataset Shape**

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# #### **Column Names**

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### **Dataset Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### **Statistical Summary**

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# #### **Unique Values Per Column**

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# #### **Numerical Columns**

# %%
num_cols = df.select_dtypes(include="number").columns

num_cols
# Out:
# Index(['release_year'], dtype='object')

# %% [markdown]
# #### **Categorical Columns**

# %%
cat_cols = df.select_dtypes(include=["object", "string"]).columns

cat_cols
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### **Convert Date Columns**

# %%
df["date_added"] = pd.to_datetime(df["date_added"], errors='coerce')

# %% [markdown]
# #### **Date Columns**

# %%
date_cols = df.select_dtypes(include="datetime").columns
date_cols
# Out:
# Index(['date_added'], dtype='object')

# %% [markdown]
# #### **Missing Value Analysis**

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### **Duplicate Rows**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### **Check Logical Bounds & Outliers**

# %%
print("\n Release Year Distribution")
print(df["release_year"].describe())
# Out:
#  Release Year Distribution
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %% [markdown]
# #### **Check for any invalid future release years**

# %%
invalid_years = df[df["release_year"] > 2026]
print(f"Rows with invalid future release years: {len(invalid_years)}")
# Out:
# Rows with invalid future release years: 0

# %% [markdown]
# #### **Data Quality Issue Log**

# %% [markdown]
# ## Data Quality Issues
#
# | Issue | Column | Observation |
# | :--- | :--- | :--- |
# | Missing Values | director / cast / country / date_added / rating | Null values detected in multiple text columns |
# | Duplicates | Entire Dataset | Check required for duplicate `show_id` entries |
# | Mixed Formats | duration | Contains mixed measurement strings ('Seasons' vs 'min') |
# | Datatype Issues | date_added | Needs conversion from string object to datetime |
# | Incomplete Data | rating / duration | Empty or misaligned categories present |

# %% [markdown]
# #### **Initial Observations**

# %% [markdown]
# ## **Initial Observations**

# %% [markdown]
# * Dataset contains a mix of categorical text features and numeric/temporal variables
# * The 'date_added' column contains object text strings requiring conversion to datetime formats
# * Missing values are present across several core columns such as 'director', 'cast', and 'country'
# * Categorical distributions show heavy representation from 'United States' and 'TV-MA' ratings
# * The 'duration' feature uses mixed metric terminology requiring parsing ('Seasons' vs. 'min')
# * Dataset is highly suitable for advanced EDA, content recommendations, and text-based analytics
